# %% [markdown]
# <h2>Useful pip command</h2>

# %% [markdown]
# <table style="width:100%">
#     <tr>
#         <th>command</th>
#         <th>用途</th>
#     </tr>
#     <tr>
#         <td>pip list</td>
#         <td>已安装module列表</td>
#     </tr>
#     <tr>
#         <td>pip search</td>
#         <td>查找module</td>
#     </tr>
#     <tr>
#         <td>pip install/uninstall</td>
#         <td>安装module/卸载</td>
#     </tr>
#     <tr>
#         <td>pip list --outdated</td>
#         <td>查看module最新版本</td>
#     </tr>
#     <tr>
#         <td>pip install --upgrade</td>
#         <td>更新版本</td>
#     </tr>
#     <tr>
#         <td>pip freeze > filename.txt</td>
#         <td>输出所有module和版本，便于其他人直接安装</td>
#     </tr>
#     <tr>
#         <td>pip install -r filename.txt</td>
#         <td>直接安装pip freeze出来的所有module和对应的版本</td>
#     </tr>
#     <tr>
#         <td>pip freeze --local | grep -v '^\-e' | cut -d = -f 1 | xargs -n1 pip install -U</td>
#         <td>更新所有outdated的module</td>
#     </tr>
# </table>

# %% [markdown]
# <h2>Virsualenv</h2>

# %% [markdown]
# <table style="width:100%">
#     <tr>
#         <th>command</th>
#         <th>用途</th>
#     </tr>
#     <tr>
#         <td>mkdir Environment/ cd Environment</td>
#         <td>生成environment文件夹用来储存所有environment文件</td>
#     </tr>
#     <tr>
#         <td>virtualenv test_project</td>
#         <td>生成新的virtual environment</td>
#     </tr>
#     <tr>
#         <td>source test_project/bin/activate</td>
#         <td>使环境生效</td>
#     </tr>
#     <tr>
#         <td>deactivate</td>
#         <td>关闭virualenv环境</td>
#     </tr>
#     <tr>
#         <td>rm -rf test_project/</td>
#         <td>删除环境</td>
#     </tr>
#     <tr>
#         <td>virtualenv -p /usr/bin/python2.6 test_project</td>
#         <td>生成特定python版本的环境</td>
#     </tr>
# </table>

# %% [markdown]
# <h2>Anaconda</h2>

# %% [markdown]
# <h4>conda commend</h4>
# <table  style="width:100%">
#     <tr>
#         <th>command</th>
#         <th>用途</th>
#     </tr>
#     <tr>
#         <td>conda create --name <font color="red">test_env</font> pyhive (至少需要有一个初始包，没有可以用pip)</td>
#         <td>生成conda环境</td>
#     </tr>
#     <tr>
#         <td>conda activate <font color="red">test_env</font></td>
#         <td>使环境生效</td>
#     </tr>
#     <tr>
#         <td>conda deactivate</td>
#         <td>关闭环境</td>
#     </tr>
#     <tr>
#         <td>conda create --name python=2.7 <font color="red">test_env</font> pyhive</td>
#         <td>生成特定python版本的环境</td>
#     </tr>
#     <tr>
#         <td>conda env list</td>
#         <td>所有环境列表，有星号的是正在生效的</td>
#     </tr>
#     <tr>
#         <td>conda env remove --name <font color="red">test_env</font></td>
#         <td>删除环境</td>
#     </tr>
# </table>

# %% [markdown]
# <h4>Use pip in ipython</h4>
# <table  style="width:100%">
#     <tr>
#         <th>command</th>
#         <th>用途</th>
#     </tr>
#     <tr>
#         <td>ipython profile create</td>
#         <td>生成ipython配置文件</td>
#     </tr>
#     <tr>
#         <td>ipython locate/ cd ...</td>
#         <td>找到ipython配置文件的位置并进入文件夹</td>
#     </tr>
#     <tr>
#         <td>vi profile_default/ipython_config.py</td>
#         <td>更改配置文件</td>
#     </tr>
#     <tr rowspan='3'>
#         <td>c.InteractiveShellApp.exec_lines = [<br>
#           &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'import sys; sys.path.append("/path/to/your/module")'<br>
#         ]</td>
#         <td>找到这行命令并修改（注意将comment去掉）</td>
#     </tr>
#     <tr>
#         <td>参考资料</td>
#         <td>https://stackoverflow.com/questions/34976803/sys-path-different-in-jupyter-and-python-how-to-import-own-modules-in-jupyter</td>
#     </tr>
# </table>

# %% [markdown]
# <h2>Manage multiple projects</h2>

# %% [markdown]
# <table style="width:100%;text-align:center">
#     <tr>
#         <th>command</th>
#         <th>用途</th>
#     </tr>
#     <tr>
#         <td>conda env export > environment.yaml</td>
#         <td>生成储存环境中module和其version的yaml文件</td>
#     </tr>
#     <tr>
#         <td>见下格markdown
#         </td>
#         <td>在PROMPT_COMMAND中添加conda_auto_env函数(~/.bash_profile)</td>
#     </tr>
# </table>

# %%
# %%bash
# # Auto activate conda environments
# function conda_auto_env() {
#   if [ -e "environment.yaml" ]; then
#     ENV_NAME=$(head -n 1 environment.yaml | cut -f2 -d ' ')
#   # Check if you are already in the environment
#     if [[ $CONDA_PREFIX != *$ENV_NAME* ]]; then
#     # Try to activate environment
#       source activate $ENV_NAME &>/dev/null
#     fi
#   fi
# }
#
# export PROMPT_COMMAND="conda_auto_env;$PROMPT_COMMAND"

# %% [markdown]
# <h2>Jupyter Notebook</h2>

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# <table style="width:100%;text-align:center">
#     <tr>
#         <th>command</th>
#         <th>用途</th>
#     </tr>
#     <tr>
#         <td>%%HTML</td>
#         <td>Directly write html code down with power of insert pictures and videos</td>
#     </tr>
#     <tr>
#         <td>%matplotlib inline</td>
#         <td>insert plot directly into jupyter notebook</td>
#     </tr>
#     <tr>
#         <td>%%timeit</td>
#         <td>give estimate time of running codes</td>
#     </tr>
# </table>
